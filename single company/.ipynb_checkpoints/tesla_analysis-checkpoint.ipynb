# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

style.use('ggplot')

# start = dt.datetime(2000,1,1)
# end = dt.datetime(2019,12,31)

# df = web.DataReader('TSLA', 'yahoo', start,end)
# Out:
# c:\users\julio\appdata\local\programs\python\python38\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
df.head()
# Out:
#              High        Low       Open      Close    Volume  Adj Close
# Date
# 2010-06-29  25.00  17.540001  19.000000  23.889999  18766300  23.889999
# 2010-06-30  30.42  23.299999  25.790001  23.830000  17187100  23.830000
# 2010-07-01  25.92  20.270000  25.000000  21.959999   8218800  21.959999
# 2010-07-02  23.10  18.709999  23.000000  19.200001   5139800  19.200001
# 2010-07-06  20.00  15.830000  20.000000  16.110001   6866900  16.110001

# %%
# df.to_csv('tesla.csv')

# %%
df = pd.read_csv('tesla.csv', parse_dates=True, index_col=0)

# %%
df.head()
# Out:
#              High        Low       Open      Close    Volume  Adj Close
# Date
# 2010-06-29  25.00  17.540001  19.000000  23.889999  18766300  23.889999
# 2010-06-30  30.42  23.299999  25.790001  23.830000  17187100  23.830000
# 2010-07-01  25.92  20.270000  25.000000  21.959999   8218800  21.959999
# 2010-07-02  23.10  18.709999  23.000000  19.200001   5139800  19.200001
# 2010-07-06  20.00  15.830000  20.000000  16.110001   6866900  16.110001

# %%
df.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-12-24  425.470001  412.690002  418.359985  425.250000   8054700
# 2019-12-26  433.480011  426.350006  427.910004  430.940002  10633900
# 2019-12-27  435.309998  426.109985  435.000000  430.380005   9945700
# 2019-12-30  429.000000  409.260010  428.790009  414.700012  12586400
# 2019-12-31  421.290009  402.079987  405.000000  418.329987  10285700
#
#              Adj Close
# Date
# 2019-12-24  425.250000
# 2019-12-26  430.940002
# 2019-12-27  430.380005
# 2019-12-30  414.700012
# 2019-12-31  418.329987

# %%
df['Adj Close'].plot()

# %%
df['100ma'] = df['Adj Close'].rolling(window=100, min_periods=0).mean()

# %%
df.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2010-11-17  30.750000  28.610001  30.200001  29.490000   750000  29.490000
# 2010-11-18  30.740000  28.920000  30.670000  29.889999   956100  29.889999
# 2010-11-19  31.370001  29.700001  30.160000  30.990000  1150500  30.990000
# 2010-11-22  33.450001  31.500000  31.570000  33.400002  1529700  33.400002
# 2010-11-23  35.680000  32.189999  33.290001  34.570000  1577800  34.570000
#
#                 100ma
# Date
# 2010-11-17  29.490000
# 2010-11-18  29.690000
# 2010-11-19  30.123333
# 2010-11-22  30.942500
# 2010-11-23  31.668000

# %%
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-12-24  425.470001  412.690002  418.359985  425.250000   8054700
# 2019-12-26  433.480011  426.350006  427.910004  430.940002  10633900
# 2019-12-27  435.309998  426.109985  435.000000  430.380005   9945700
# 2019-12-30  429.000000  409.260010  428.790009  414.700012  12586400
# 2019-12-31  421.290009  402.079987  405.000000  418.329987  10285700
#
#              Adj Close     100ma
# Date
# 2019-12-24  425.250000  283.5870
# 2019-12-26  430.940002  285.6132
# 2019-12-27  430.380005  287.6095
# 2019-12-30  414.700012  289.4223
# 2019-12-31  418.329987  291.2226

# %%
df.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2010-11-17  30.750000  28.610001  30.200001  29.490000   750000  29.490000
# 2010-11-18  30.740000  28.920000  30.670000  29.889999   956100  29.889999
# 2010-11-19  31.370001  29.700001  30.160000  30.990000  1150500  30.990000
# 2010-11-22  33.450001  31.500000  31.570000  33.400002  1529700  33.400002
# 2010-11-23  35.680000  32.189999  33.290001  34.570000  1577800  34.570000
#
#               100ma
# Date
# 2010-11-17  20.9879
# 2010-11-18  21.0479
# 2010-11-19  21.1195
# 2010-11-22  21.2339
# 2010-11-23  21.3876

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

ax1.plot(df.index, df['100ma'])
ax1.plot(df.index, df['Adj Close'])
ax2.bar(df.index, df['Volume'])
# Out:
# <BarContainer object of 2295 artists>

# %%
df_ohlc = df['Adj Close'].resample('10D').ohlc()
df_volume = df['Volume'].resample('10d').sum()

# %%
df_ohlc.head()
# Out:
#                  open       high        low      close
# Date
# 2010-11-17  29.490000  35.470001  29.490000  35.320000
# 2010-11-27  34.330002  35.330002  30.309999  30.309999
# 2010-12-07  31.559999  32.369999  28.530001  30.809999
# 2010-12-17  31.360001  32.630001  30.090000  30.090000
# 2010-12-27  25.549999  27.730000  25.549999  26.830000

# %%
import mplfinance as mpf
import matplotlib.dates as mdates

# %%
df_ohlc.reset_index(inplace=True)

# %%
df_ohlc.head()
# Out:
#         Date       open       high        low      close
# 0 2010-11-17  29.490000  35.470001  29.490000  35.320000
# 1 2010-11-27  34.330002  35.330002  30.309999  30.309999
# 2 2010-12-07  31.559999  32.369999  28.530001  30.809999
# 3 2010-12-17  31.360001  32.630001  30.090000  30.090000
# 4 2010-12-27  25.549999  27.730000  25.549999  26.830000

# %%
df_ohlc['Date'] = df_ohlc['Date'].map(mdates.date2num)

# %%
df_ohlc.head()
# Out:
#        Date       open       high        low      close
# 0  734093.0  29.490000  35.470001  29.490000  35.320000
# 1  734103.0  34.330002  35.330002  30.309999  30.309999
# 2  734113.0  31.559999  32.369999  28.530001  30.809999
# 3  734123.0  31.360001  32.630001  30.090000  30.090000
# 4  734133.0  25.549999  27.730000  25.549999  26.830000

# %%
mpf.plot(df_ohlc,type='candle', style='charles')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\julio\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'High'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-93409a7189f6> in <module>
# ...

# %%
df_ohlc['Open'] = df_ohlc['open']
df_ohlc.drop('open',axis=1)
df_ohlc['High'] = df_ohlc['high']
df_ohlc.drop('high',axis=1)
df_ohlc['Low'] = df_ohlc['low']
df_ohlc.drop('low',axis=1)
df_ohlc['Close'] = df_ohlc['close']
df_ohlc.drop('close',axis=1)
# Out:
#                   open        high         low        Open        High  \
# Date
# 2010-11-17   29.490000   35.470001   29.490000   29.490000   35.470001
# 2010-11-27   34.330002   35.330002   30.309999   34.330002   35.330002
# 2010-12-07   31.559999   32.369999   28.530001   31.559999   32.369999
# 2010-12-17   31.360001   32.630001   30.090000   31.360001   32.630001
# 2010-12-27   25.549999   27.730000   25.549999   25.549999   27.730000
# ...                ...         ...         ...         ...         ...
# 2019-11-20  352.220001  354.829987  328.920013  352.220001  354.829987
# 2019-11-30  334.869995  339.529999  330.369995  334.869995  339.529999
# 2019-12-10  348.839996  404.040009  348.839996  348.839996  404.040009
# 2019-12-20  405.589996  430.940002  405.589996  405.589996  430.940002
# 2019-12-30  414.700012  418.329987  414.700012  414.700012  418.329987
#
#                    Low       Close
# Date
# 2010-11-17   29.490000   35.320000
# ...

# %%
df_ohlc.drop('low',axis=1)
# Out:
#                   open        high       close        Open        High  \
# Date
# 2010-11-17   29.490000   35.470001   35.320000   29.490000   35.470001
# 2010-11-27   34.330002   35.330002   30.309999   34.330002   35.330002
# 2010-12-07   31.559999   32.369999   30.809999   31.559999   32.369999
# 2010-12-17   31.360001   32.630001   30.090000   31.360001   32.630001
# 2010-12-27   25.549999   27.730000   26.830000   25.549999   27.730000
# ...                ...         ...         ...         ...         ...
# 2019-11-20  352.220001  354.829987  329.940002  352.220001  354.829987
# 2019-11-30  334.869995  339.529999  339.529999  334.869995  339.529999
# 2019-12-10  348.839996  404.040009  404.040009  348.839996  404.040009
# 2019-12-20  405.589996  430.940002  430.380005  405.589996  430.940002
# 2019-12-30  414.700012  418.329987  418.329987  414.700012  418.329987
#
#                    Low       Close
# Date
# 2010-11-17   29.490000   35.320000
# ...

# %%
#df_ohlc.drop('open',axis=1,inplace=True)
df_ohlc.drop('high',axis=1,inplace=True)
df_ohlc.drop('close',axis=1,inplace=True)

# %%
df.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2010-11-17  30.750000  28.610001  30.200001  29.490000   750000  29.490000
# 2010-11-18  30.740000  28.920000  30.670000  29.889999   956100  29.889999
# 2010-11-19  31.370001  29.700001  30.160000  30.990000  1150500  30.990000
# 2010-11-22  33.450001  31.500000  31.570000  33.400002  1529700  33.400002
# 2010-11-23  35.680000  32.189999  33.290001  34.570000  1577800  34.570000
#
#                 100ma
# Date
# 2010-11-17  29.490000
# 2010-11-18  29.690000
# 2010-11-19  30.123333
# 2010-11-22  30.942500
# 2010-11-23  31.668000

# %%
df_ohlc.head()
# Out:
#                  Open       High        Low      Close
# Date
# 2010-11-17  29.490000  35.470001  29.490000  35.320000
# 2010-11-27  34.330002  35.330002  30.309999  30.309999
# 2010-12-07  31.559999  32.369999  28.530001  30.809999
# 2010-12-17  31.360001  32.630001  30.090000  30.090000
# 2010-12-27  25.549999  27.730000  25.549999  26.830000

# %%
# %matplotlib inline
mpf.plot(df_ohlc,type='candle', style='charles')
